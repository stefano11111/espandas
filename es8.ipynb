# %%
# Write a Pandas program to extract specific records from the world alcohol consumption dataset, 
# starting from the 2nd row, and selecting every 5th row thereafter.

import pandas as pd
db=pd.read_csv("World_Alcohol_Dataset - MAIN.csv")
print(db.iloc[1::5])
# Out:
#                       country beer_servings spirit_servings wine_servings  \
# 1                     Albania            89             132            54
# 6                     Armenia            21             179            11
# 11                    Bahrain            42              63             7
# 16                     Belize           263             114             8
# 21                   Botswana           173              35            35
# 26                    Burundi            88               0             0
# 31   Central African Republic            17               2             1
# 36                    Comoros             1               3             1
# 41                       Cuba            93             137             5
# 46         Dominican Republic           193             147             9
# 51          Equatorial Guinea            92               0           233
# 56                    Finland           263             133            97
# ...
