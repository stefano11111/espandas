# %%
# Write a Pandas program to display the dataframe in Heatmap style.

import pandas as pd
import random
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns



db=pd.DataFrame({random.randint(0,100):[random.randint(0,101) for _ in range (10)],
                 random.randint(0,100):[random.randint(0,101) for _ in range (10)],
                 random.randint(0,100):[random.randint(0,101) for _ in range (10)],
                 random.randint(0,100):[random.randint(0,101) for _ in range (10)],
                 })
l=random.randint(5,15)
for x in range(l):
    a=random.randint(1,9)
    b=random.randint(0,3)
    db.iloc[a,b]=np.nan
print(db)
# Out:
#       35    66    68  73
# 0   48.0  28.0  52.0  31
# 1   79.0  62.0   NaN  93
# 2   20.0   7.0  52.0  77
# 3    0.0  42.0   NaN  85
# 4    NaN  42.0  52.0  33
# 5    NaN  70.0  64.0  46
# 6   16.0  86.0   NaN  13
# 7   75.0  34.0   NaN  63
# 8  100.0   NaN  40.0  37
# 9   44.0  44.0  40.0  98

# %%
db.style.background_gradient() #usare background_gradient
# Out:
# <style type="text/css">
# #T_8771b_row0_col0 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_8771b_row0_col1 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_8771b_row0_col2, #T_8771b_row2_col2, #T_8771b_row4_col2 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_8771b_row0_col3 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_8771b_row1_col0 {
#   background-color: #0569a4;
#   color: #f1f1f1;
# }
# #T_8771b_row1_col1 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_8771b_row1_col2, #T_8771b_row3_col2, #T_8771b_row4_col0, #T_8771b_row5_col0, #T_8771b_row6_col2, #T_8771b_row7_col2, #T_8771b_row8_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_8771b_row1_col3 {
#   background-color: #034871;
#   color: #f1f1f1;
# }
# #T_8771b_row2_col0 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_8771b_row2_col1, #T_8771b_row3_col0, #T_8771b_row6_col3, #T_8771b_row8_col2, #T_8771b_row9_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_8771b_row2_col3, #T_8771b_row7_col0 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_8771b_row3_col1, #T_8771b_row4_col1 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_8771b_row3_col3 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_8771b_row4_col3 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_8771b_row5_col1 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_8771b_row5_col2, #T_8771b_row6_col1, #T_8771b_row8_col0, #T_8771b_row9_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_8771b_row5_col3 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_8771b_row6_col0 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_8771b_row7_col1 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_8771b_row7_col3 {
#   background-color: #4897c4;
#   color: #f1f1f1;
# }
# #T_8771b_row8_col3 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_8771b_row9_col0 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_8771b_row9_col1 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8771b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8771b_level0_col0" class="col_heading level0 col0" >35</th>
#       <th id="T_8771b_level0_col1" class="col_heading level0 col1" >66</th>
#       <th id="T_8771b_level0_col2" class="col_heading level0 col2" >68</th>
#       <th id="T_8771b_level0_col3" class="col_heading level0 col3" >73</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8771b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8771b_row0_col0" class="data row0 col0" >48.000000</td>
#       <td id="T_8771b_row0_col1" class="data row0 col1" >28.000000</td>
#       <td id="T_8771b_row0_col2" class="data row0 col2" >52.000000</td>
#       <td id="T_8771b_row0_col3" class="data row0 col3" >31</td>
#     </tr>
#     <tr>
#       <th id="T_8771b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8771b_row1_col0" class="data row1 col0" >79.000000</td>
#       <td id="T_8771b_row1_col1" class="data row1 col1" >62.000000</td>
#       <td id="T_8771b_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_8771b_row1_col3" class="data row1 col3" >93</td>
#     </tr>
#     <tr>
#       <th id="T_8771b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8771b_row2_col0" class="data row2 col0" >20.000000</td>
#       <td id="T_8771b_row2_col1" class="data row2 col1" >7.000000</td>
#       <td id="T_8771b_row2_col2" class="data row2 col2" >52.000000</td>
#       <td id="T_8771b_row2_col3" class="data row2 col3" >77</td>
#     </tr>
#     <tr>
#       <th id="T_8771b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8771b_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_8771b_row3_col1" class="data row3 col1" >42.000000</td>
#       <td id="T_8771b_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_8771b_row3_col3" class="data row3 col3" >85</td>
#     </tr>
#     <tr>
#       <th id="T_8771b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8771b_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_8771b_row4_col1" class="data row4 col1" >42.000000</td>
#       <td id="T_8771b_row4_col2" class="data row4 col2" >52.000000</td>
#       <td id="T_8771b_row4_col3" class="data row4 col3" >33</td>
#     </tr>
#     <tr>
#       <th id="T_8771b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8771b_row5_col0" class="data row5 col0" >nan</td>
#       <td id="T_8771b_row5_col1" class="data row5 col1" >70.000000</td>
#       <td id="T_8771b_row5_col2" class="data row5 col2" >64.000000</td>
#       <td id="T_8771b_row5_col3" class="data row5 col3" >46</td>
#     </tr>
#     <tr>
#       <th id="T_8771b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8771b_row6_col0" class="data row6 col0" >16.000000</td>
#       <td id="T_8771b_row6_col1" class="data row6 col1" >86.000000</td>
#       <td id="T_8771b_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_8771b_row6_col3" class="data row6 col3" >13</td>
#     </tr>
#     <tr>
#       <th id="T_8771b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8771b_row7_col0" class="data row7 col0" >75.000000</td>
#       <td id="T_8771b_row7_col1" class="data row7 col1" >34.000000</td>
#       <td id="T_8771b_row7_col2" class="data row7 col2" >nan</td>
#       <td id="T_8771b_row7_col3" class="data row7 col3" >63</td>
#     </tr>
#     <tr>
#       <th id="T_8771b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8771b_row8_col0" class="data row8 col0" >100.000000</td>
#       <td id="T_8771b_row8_col1" class="data row8 col1" >nan</td>
#       <td id="T_8771b_row8_col2" class="data row8 col2" >40.000000</td>
#       <td id="T_8771b_row8_col3" class="data row8 col3" >37</td>
#     </tr>
#     <tr>
#       <th id="T_8771b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8771b_row9_col0" class="data row9 col0" >44.000000</td>
#       <td id="T_8771b_row9_col1" class="data row9 col1" >44.000000</td>
#       <td id="T_8771b_row9_col2" class="data row9 col2" >40.000000</td>
#       <td id="T_8771b_row9_col3" class="data row9 col3" >98</td>
#     </tr>
#   </tbody>
# </table>
